# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define the grid search results
results = {
    'param1': [value1, value2, value3],
    'param2': [value4, value5, value6],
    'param3': [value7, value8, value9],
    'mean_score': [score1, score2, score3],
    'std_score': [std1, std2, std3]
}

# Convert the results dictionary to a pandas DataFrame
df_results = pd.DataFrame(results)

# Sort the DataFrame by the mean_score column in descending order
df_results = df_results.sort_values('mean_score', ascending=False)

# Set the parameter columns as the DataFrame index
df_results = df_results.set_index(['param1', 'param2', 'param3'])

# Create a table plot using pandas styler
table = df_results.style.format({
    'mean_score': '{:.4f}',
    'std_score': '{:.4f}'
})

# Set the style properties for the table
table = table.set_table_styles([
    {'selector': 'th', 'props': [('text-align', 'center')]},
    {'selector': 'td', 'props': [('text-align', 'center')]}
])

# Render the table plot
table_plot = table.hide_index().set_caption('Grid Search Results')

# Display the table plot
table_plot
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 9
#       6 valid_acc = [0.2624, 0.2627, 0.2697, 0.3010, 0.2299, 0.3852, 0.4383, 0.4522, 0.4372, 0.4694, 0.4772, 0.4885, 0.5022, 0.5094, 0.5219, 0.4865, 0.5126, 0.4848, 0.4296, 0.5234, 0.5057, 0.5480, 0.5222, 0.5100, 0.4766, 0.5039, 0.5396, 0.5451, 0.5504, 0.5344, 0.5405, 0.5315, 0.5327, 0.5222, 0.5152, 0.5306, 0.5007, 0.5300, 0.5390, 0.4874, 0.5666, 0.5184, 0.5556, 0.5486, 0.5695, 0.5448, 0.5567, 0.5533, 0.5530, 0.5765, 0.5637, 0.5666, 0.5724, 0.5498, 0.5640, 0.5588, 0.5498]
#       8 plt.plot(epochs, train_loss, label='Training Loss')
# ----> 9 plt.plot(epochs, valid_acc, label='Validation Accuracy')
#      10 plt.xlabel('Epochs')
#      11 plt.ylabel('Loss / Accuracy')
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/pyplot.py:2812, in plot(scalex, scaley, data, *args, **kwargs)
# ...
